# %%
# import system libs
import os
import time
import shutil
import pathlib
import itertools
from PIL import Image

# import data handling tools
import zipfile
import cv2
import numpy as np
import pandas as pd
from scipy.ndimage import median_filter
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import OneHotEncoder ,LabelEncoder

# import Deep learning Libraries

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense,InputLayer, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from keras.callbacks import EarlyStopping
from keras.regularizers import l2
from keras.utils import to_categorical
# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# modules loaded

# %%
dataset_path = '/kaggle/input/fer2013/train'


data = []
labels = []
paths = []
# Iterate through the dataset directory
for class_name in os.listdir(dataset_path):
    class_dir = os.path.join(dataset_path, class_name)
    for img_name in os.listdir(class_dir):
        img_path = os.path.join(class_dir, img_name)
        paths.append(img_path)
        img = cv2.imread(img_path) 
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        data.append(img)
        labels.append(class_name)

# %%
dataset_path = '/kaggle/input/fer2013/test'

for class_name in os.listdir(dataset_path):
    class_dir = os.path.join(dataset_path, class_name)
    for img_name in os.listdir(class_dir):
        img_path = os.path.join(class_dir, img_name)
        paths.append(img_path)
        img = cv2.imread(img_path) 
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        data.append(img)
        labels.append(class_name)
        
        
df = pd.DataFrame({'data': paths, 'label': labels})
data = np.array(data)
labels = np.array(labels)

# %%
df
# Out:
#                                                     data     label
# 0      /kaggle/input/fer2013/train/surprise/Training_...  surprise
# 1      /kaggle/input/fer2013/train/surprise/Training_...  surprise
# 2      /kaggle/input/fer2013/train/surprise/Training_...  surprise
# 3      /kaggle/input/fer2013/train/surprise/Training_...  surprise
# 4      /kaggle/input/fer2013/train/surprise/Training_...  surprise
# ...                                                  ...       ...
# 35882  /kaggle/input/fer2013/test/happy/PublicTest_13...     happy
# 35883  /kaggle/input/fer2013/test/happy/PublicTest_70...     happy
# 35884  /kaggle/input/fer2013/test/happy/PublicTest_24...     happy
# 35885  /kaggle/input/fer2013/test/happy/PrivateTest_7...     happy
# 35886  /kaggle/input/fer2013/test/happy/PublicTest_92...     happy
#
# [35887 rows x 2 columns]

# %%
def display_random_images(images, labels, num_images=5):
    num_total_images = len(images)
    random_indices = np.random.choice(num_total_images, size=num_images, replace=False)

    fig, axes = plt.subplots(1, num_images, figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        axes[i].imshow(images[idx])
        axes[i].set_title(labels[idx])
        axes[i].axis('off')
    plt.tight_layout()
    plt.show()

display_random_images(data, labels)

# %%
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# %%
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42 , stratify = labels)

# %%
y_train = to_categorical(y_train, num_classes=7)  # Convert training labels to one-hot encoded format
y_test = to_categorical(y_test, num_classes=7)

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
print(type(x_train), x_train.shape)
print(type(y_train), y_train.shape)
print(type(x_test), x_test.shape)
print(type(y_test), y_test.shape)

print("x_train data type:", x_train.dtype)
print("y_train data type:", y_train.dtype)
print("x_test data type:", x_test.dtype)
print("y_test data type:", y_test.dtype)
# Out:
# <class 'numpy.ndarray'> (28709, 48, 48, 3)
# <class 'numpy.ndarray'> (28709, 7)
# <class 'numpy.ndarray'> (7178, 48, 48, 3)
# <class 'numpy.ndarray'> (7178, 7)
# x_train data type: float64
# y_train data type: float32
# x_test data type: float64
# y_test data type: float32

# %%
ann_model = Sequential()

ann_model.add(InputLayer(input_shape=(48, 48, 3)))
ann_model.add(Flatten())

ann_model.add(Dense(64, activation='leaky_relu'))
ann_model.add(BatchNormalization())
ann_model.add(Dropout(0.2))

ann_model.add(Dense(7, activation='softmax'))

ann_model.compile(optimizer=Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])
ann_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 6912)              0
#
#  dense_21 (Dense)            (None, 64)                442432
#
#  batch_normalization_18 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_19 (Dropout)        (None, 64)                0
#
#  dense_22 (Dense)            (None, 7)                 455
#
# =================================================================
# Total params: 443143 (1.69 MB)
# Trainable params: 443015 (1.69 MB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________

# %%
history_ann = ann_model.fit(x_train,y_train,validation_data = (x_test, y_test),epochs = 40 )
# Out:
# Epoch 1/40
# 898/898 [==============================] - 6s 5ms/step - loss: 1.8113 - accuracy: 0.3051 - val_loss: 1.7187 - val_accuracy: 0.3254
# Epoch 2/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.6828 - accuracy: 0.3450 - val_loss: 1.6479 - val_accuracy: 0.3631
# Epoch 3/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.6448 - accuracy: 0.3592 - val_loss: 1.6888 - val_accuracy: 0.3214
# Epoch 4/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.6297 - accuracy: 0.3653 - val_loss: 1.7178 - val_accuracy: 0.3323
# Epoch 5/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.6206 - accuracy: 0.3729 - val_loss: 1.6350 - val_accuracy: 0.3718
# Epoch 6/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.6085 - accuracy: 0.3785 - val_loss: 1.6769 - val_accuracy: 0.3586
# Epoch 7/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.6029 - accuracy: 0.3779 - val_loss: 1.7136 - val_accuracy: 0.3408
# Epoch 8/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5981 - accuracy: 0.3812 - val_loss: 1.6638 - val_accuracy: 0.3568
# Epoch 9/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5908 - accuracy: 0.3840 - val_loss: 1.6397 - val_accuracy: 0.3597
# Epoch 10/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5879 - accuracy: 0.3821 - val_loss: 1.7417 - val_accuracy: 0.3346
# Epoch 11/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5834 - accuracy: 0.3884 - val_loss: 1.7819 - val_accuracy: 0.3220
# Epoch 12/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5784 - accuracy: 0.3882 - val_loss: 1.6655 - val_accuracy: 0.3435
# Epoch 13/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5726 - accuracy: 0.3905 - val_loss: 1.6252 - val_accuracy: 0.3753
# Epoch 14/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5690 - accuracy: 0.3934 - val_loss: 1.6789 - val_accuracy: 0.3415
# Epoch 15/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5674 - accuracy: 0.3960 - val_loss: 1.6636 - val_accuracy: 0.3396
# Epoch 16/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5648 - accuracy: 0.3938 - val_loss: 1.6076 - val_accuracy: 0.3752
# Epoch 17/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5536 - accuracy: 0.3994 - val_loss: 1.6694 - val_accuracy: 0.3592
# Epoch 18/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5516 - accuracy: 0.4008 - val_loss: 1.6499 - val_accuracy: 0.3626
# Epoch 19/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5480 - accuracy: 0.4031 - val_loss: 1.7116 - val_accuracy: 0.3632
# Epoch 20/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5453 - accuracy: 0.4024 - val_loss: 1.6633 - val_accuracy: 0.3469
# Epoch 21/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5435 - accuracy: 0.4050 - val_loss: 1.6523 - val_accuracy: 0.3546
# Epoch 22/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5388 - accuracy: 0.4057 - val_loss: 1.6381 - val_accuracy: 0.3638
# Epoch 23/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5326 - accuracy: 0.4092 - val_loss: 1.6187 - val_accuracy: 0.3692
# Epoch 24/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5316 - accuracy: 0.4087 - val_loss: 1.6270 - val_accuracy: 0.3716
# Epoch 25/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5273 - accuracy: 0.4130 - val_loss: 1.7587 - val_accuracy: 0.3395
# Epoch 26/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5276 - accuracy: 0.4081 - val_loss: 1.6852 - val_accuracy: 0.3381
# Epoch 27/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5240 - accuracy: 0.4130 - val_loss: 1.9223 - val_accuracy: 0.3279
# Epoch 28/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5195 - accuracy: 0.4157 - val_loss: 1.6606 - val_accuracy: 0.3611
# Epoch 29/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5139 - accuracy: 0.4202 - val_loss: 1.6497 - val_accuracy: 0.3505
# Epoch 30/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5116 - accuracy: 0.4162 - val_loss: 1.6515 - val_accuracy: 0.3633
# Epoch 31/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5106 - accuracy: 0.4199 - val_loss: 1.6108 - val_accuracy: 0.3787
# Epoch 32/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5087 - accuracy: 0.4168 - val_loss: 1.6444 - val_accuracy: 0.3618
# Epoch 33/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5032 - accuracy: 0.4219 - val_loss: 1.6548 - val_accuracy: 0.3656
# Epoch 34/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.5017 - accuracy: 0.4237 - val_loss: 1.6946 - val_accuracy: 0.3402
# Epoch 35/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.4994 - accuracy: 0.4217 - val_loss: 1.7331 - val_accuracy: 0.3381
# Epoch 36/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.4965 - accuracy: 0.4241 - val_loss: 1.6261 - val_accuracy: 0.3633
# Epoch 37/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.4990 - accuracy: 0.4224 - val_loss: 1.6331 - val_accuracy: 0.3742
# Epoch 38/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.4925 - accuracy: 0.4241 - val_loss: 1.7280 - val_accuracy: 0.3327
# Epoch 39/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.4856 - accuracy: 0.4279 - val_loss: 1.6523 - val_accuracy: 0.3511
# Epoch 40/40
# 898/898 [==============================] - 4s 4ms/step - loss: 1.4847 - accuracy: 0.4282 - val_loss: 1.6955 - val_accuracy: 0.3520

# %%
# Define needed variables
tr_acc = history_ann.history['accuracy']
tr_loss = history_ann.history['loss']
val_acc = history_ann.history['val_accuracy']
val_loss = history_ann.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
model.save('ann_model_optimal.h5')

# %% [markdown]
# # Data Augmantation

# %%
strat = df['label']
train_df,validate_df = train_test_split(df,train_size = 0.80,shuffle = True, random_state = 42, stratify = strat)

# %%
batch_size = 64
img_size = (48,48)
channels = 3
img_shape = (img_size[0],img_size[1],channels)

# Create different ImageDataGenerator objects for training and testing/validation sets
train_gen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range = 0.1,   
    height_shift_range = 0.1,
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True)
valid_gen = ImageDataGenerator(rescale=1./255)


# Specify the directory argument for each set
train_gen = train_gen.flow_from_dataframe(dataframe = train_df, x_col = 'data' ,y_col = 'label', target_size = img_size, class_mode = 'categorical',color_mode = 'grayscale'
                                      , shuffle = True, batch_size = batch_size)
validate_gen = valid_gen.flow_from_dataframe(dataframe = validate_df,x_col = 'data' ,y_col = 'label', target_size = img_size, class_mode = 'categorical',color_mode = 'grayscale',
                                          shuffle = True, batch_size = batch_size)
# Out:
# Found 28709 validated image filenames belonging to 7 classes.
# Found 7178 validated image filenames belonging to 7 classes.

# %% [markdown]
# # CNN

# %%
model = Sequential([
    Conv2D(64,(3,3),activation = 'relu', input_shape = (48,48,1)),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.30,seed = 42),
    
    Conv2D(128,(3,3),activation = 'relu'),
    Conv2D(128,(3,3),activation = 'relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.30,seed = 42),
    
    Conv2D(256,(3,3),activation = 'relu'),
    Conv2D(256,(3,3),activation = 'relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.30,seed = 42),
    
    Dense(512,activation = 'relu'),
    Dropout(rate =0.35,seed = 42),
    Flatten(),
    Dense(7,activation = 'softmax')
])

model.compile(optimizer = "adam" , loss = "categorical_crossentropy" , metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  batch_normalization (Batch  (None, 46, 46, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 128)       73856
#
#  conv2d_2 (Conv2D)           (None, 19, 19, 128)       147584
#
#  batch_normalization_1 (Bat  (None, 19, 19, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 9, 9, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 9, 9, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 256)         295168
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 256)         590080
#
#  batch_normalization_2 (Bat  (None, 5, 5, 256)         1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 256)         0
#
#  dense (Dense)               (None, 2, 2, 512)         131584
#
#  dropout_3 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 7)                 14343
#
# =================================================================
# Total params: 1255047 (4.79 MB)
# Trainable params: 1254151 (4.78 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
history = model.fit(x= train_gen, epochs = 50 , verbose = 1,validation_data = validate_gen,shuffle = True)
# Out:
# Epoch 1/50
# 2023-12-14 15:25:47.617410: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 449/449 [==============================] - 53s 96ms/step - loss: 1.9354 - accuracy: 0.2284 - val_loss: 1.8428 - val_accuracy: 0.1754
# Epoch 2/50
# 449/449 [==============================] - 42s 93ms/step - loss: 1.7359 - accuracy: 0.2984 - val_loss: 1.7021 - val_accuracy: 0.3101
# Epoch 3/50
# 449/449 [==============================] - 42s 94ms/step - loss: 1.6327 - accuracy: 0.3526 - val_loss: 1.7134 - val_accuracy: 0.3030
# Epoch 4/50
# 449/449 [==============================] - 43s 95ms/step - loss: 1.5647 - accuracy: 0.3860 - val_loss: 1.5938 - val_accuracy: 0.3833
# Epoch 5/50
# 449/449 [==============================] - 44s 98ms/step - loss: 1.5251 - accuracy: 0.4068 - val_loss: 1.4470 - val_accuracy: 0.4330
# Epoch 6/50
# 449/449 [==============================] - 44s 97ms/step - loss: 1.4866 - accuracy: 0.4259 - val_loss: 1.4681 - val_accuracy: 0.4340
# Epoch 7/50
# 449/449 [==============================] - 42s 93ms/step - loss: 1.4609 - accuracy: 0.4380 - val_loss: 1.4803 - val_accuracy: 0.4207
# Epoch 8/50
# 449/449 [==============================] - 42s 94ms/step - loss: 1.4299 - accuracy: 0.4512 - val_loss: 1.4075 - val_accuracy: 0.4699
# Epoch 9/50
# 449/449 [==============================] - 42s 94ms/step - loss: 1.4056 - accuracy: 0.4608 - val_loss: 1.4364 - val_accuracy: 0.4369
# Epoch 10/50
# 449/449 [==============================] - 42s 94ms/step - loss: 1.3825 - accuracy: 0.4671 - val_loss: 1.3823 - val_accuracy: 0.4684
# Epoch 11/50
# 449/449 [==============================] - 42s 93ms/step - loss: 1.3698 - accuracy: 0.4761 - val_loss: 1.3744 - val_accuracy: 0.4670
# Epoch 12/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.3469 - accuracy: 0.4861 - val_loss: 1.2607 - val_accuracy: 0.5123
# Epoch 13/50
# 449/449 [==============================] - 42s 93ms/step - loss: 1.3354 - accuracy: 0.4895 - val_loss: 1.2527 - val_accuracy: 0.5231
# Epoch 14/50
# 449/449 [==============================] - 43s 95ms/step - loss: 1.3222 - accuracy: 0.4991 - val_loss: 1.3170 - val_accuracy: 0.4985
# Epoch 15/50
# 449/449 [==============================] - 47s 104ms/step - loss: 1.3079 - accuracy: 0.4984 - val_loss: 1.3157 - val_accuracy: 0.5091
# Epoch 16/50
# 449/449 [==============================] - 45s 101ms/step - loss: 1.3009 - accuracy: 0.5053 - val_loss: 1.3530 - val_accuracy: 0.4907
# Epoch 17/50
# 449/449 [==============================] - 49s 109ms/step - loss: 1.2866 - accuracy: 0.5055 - val_loss: 1.2791 - val_accuracy: 0.5118
# Epoch 18/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.2753 - accuracy: 0.5138 - val_loss: 1.2142 - val_accuracy: 0.5425
# Epoch 19/50
# 449/449 [==============================] - 42s 94ms/step - loss: 1.2739 - accuracy: 0.5147 - val_loss: 1.1950 - val_accuracy: 0.5521
# Epoch 20/50
# 449/449 [==============================] - 47s 105ms/step - loss: 1.2701 - accuracy: 0.5174 - val_loss: 1.2966 - val_accuracy: 0.5098
# Epoch 21/50
# 449/449 [==============================] - 43s 95ms/step - loss: 1.2548 - accuracy: 0.5218 - val_loss: 1.2018 - val_accuracy: 0.5418
# Epoch 22/50
# 449/449 [==============================] - 44s 98ms/step - loss: 1.2439 - accuracy: 0.5294 - val_loss: 1.2531 - val_accuracy: 0.5237
# Epoch 23/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.2428 - accuracy: 0.5289 - val_loss: 1.3068 - val_accuracy: 0.5015
# Epoch 24/50
# 449/449 [==============================] - 42s 94ms/step - loss: 1.2321 - accuracy: 0.5355 - val_loss: 1.2127 - val_accuracy: 0.5369
# Epoch 25/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.2240 - accuracy: 0.5336 - val_loss: 1.2018 - val_accuracy: 0.5481
# Epoch 26/50
# 449/449 [==============================] - 44s 98ms/step - loss: 1.2169 - accuracy: 0.5413 - val_loss: 1.1597 - val_accuracy: 0.5609
# Epoch 27/50
# 449/449 [==============================] - 44s 99ms/step - loss: 1.2030 - accuracy: 0.5405 - val_loss: 1.1784 - val_accuracy: 0.5527
# Epoch 28/50
# 449/449 [==============================] - 44s 97ms/step - loss: 1.2066 - accuracy: 0.5428 - val_loss: 1.2767 - val_accuracy: 0.5096
# Epoch 29/50
# 449/449 [==============================] - 44s 98ms/step - loss: 1.1999 - accuracy: 0.5482 - val_loss: 1.2587 - val_accuracy: 0.5241
# Epoch 30/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.1952 - accuracy: 0.5502 - val_loss: 1.1830 - val_accuracy: 0.5521
# Epoch 31/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.1935 - accuracy: 0.5475 - val_loss: 1.1726 - val_accuracy: 0.5582
# Epoch 32/50
# 449/449 [==============================] - 44s 98ms/step - loss: 1.1814 - accuracy: 0.5520 - val_loss: 1.1578 - val_accuracy: 0.5699
# Epoch 33/50
# 449/449 [==============================] - 44s 98ms/step - loss: 1.1807 - accuracy: 0.5534 - val_loss: 1.2704 - val_accuracy: 0.5254
# Epoch 34/50
# 449/449 [==============================] - 43s 97ms/step - loss: 1.1706 - accuracy: 0.5592 - val_loss: 1.6522 - val_accuracy: 0.4048
# Epoch 35/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.1810 - accuracy: 0.5538 - val_loss: 1.1589 - val_accuracy: 0.5571
# Epoch 36/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.1649 - accuracy: 0.5586 - val_loss: 1.0993 - val_accuracy: 0.5896
# Epoch 37/50
# 449/449 [==============================] - 46s 102ms/step - loss: 1.1579 - accuracy: 0.5608 - val_loss: 1.3261 - val_accuracy: 0.5102
# Epoch 38/50
# 449/449 [==============================] - 50s 111ms/step - loss: 1.1570 - accuracy: 0.5625 - val_loss: 1.1513 - val_accuracy: 0.5646
# Epoch 39/50
# 449/449 [==============================] - 44s 97ms/step - loss: 1.1485 - accuracy: 0.5658 - val_loss: 1.1502 - val_accuracy: 0.5656
# Epoch 40/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.1445 - accuracy: 0.5657 - val_loss: 1.1819 - val_accuracy: 0.5559
# Epoch 41/50
# 449/449 [==============================] - 43s 95ms/step - loss: 1.1415 - accuracy: 0.5699 - val_loss: 1.1161 - val_accuracy: 0.5769
# Epoch 42/50
# 449/449 [==============================] - 43s 95ms/step - loss: 1.1326 - accuracy: 0.5715 - val_loss: 1.2728 - val_accuracy: 0.5150
# Epoch 43/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.1425 - accuracy: 0.5702 - val_loss: 1.2507 - val_accuracy: 0.5238
# Epoch 44/50
# 449/449 [==============================] - 43s 95ms/step - loss: 1.1331 - accuracy: 0.5700 - val_loss: 1.1364 - val_accuracy: 0.5716
# Epoch 45/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.1315 - accuracy: 0.5770 - val_loss: 1.2489 - val_accuracy: 0.5269
# Epoch 46/50
# 449/449 [==============================] - 42s 93ms/step - loss: 1.1301 - accuracy: 0.5762 - val_loss: 1.1330 - val_accuracy: 0.5658
# Epoch 47/50
# 449/449 [==============================] - 42s 94ms/step - loss: 1.1254 - accuracy: 0.5784 - val_loss: 1.3414 - val_accuracy: 0.4852
# Epoch 48/50
# 449/449 [==============================] - 43s 96ms/step - loss: 1.1935 - accuracy: 0.5530 - val_loss: 1.7932 - val_accuracy: 0.3249
# Epoch 49/50
# 449/449 [==============================] - 44s 98ms/step - loss: 1.1995 - accuracy: 0.5460 - val_loss: 1.1132 - val_accuracy: 0.5777
# Epoch 50/50
# 449/449 [==============================] - 45s 100ms/step - loss: 1.1439 - accuracy: 0.5664 - val_loss: 1.0939 - val_accuracy: 0.5844

# %%
# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
list(train_gen.class_indices.keys())
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
# Get the true labels and predicted labels for the validation set
validation_labels = validate_gen.classes
validation_pred_probs = model.predict(validate_gen)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_gen.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 113/113 [==============================] - 7s 59ms/step

# %%
model.save('model_optimal.h5')
